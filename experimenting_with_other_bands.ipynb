# %%
import os
from glob import glob
import importlib
from geedownload import geeutils
importlib.reload(geeutils)
from geedownload import tiffutils
importlib.reload(tiffutils)

data_dir = os.path.join('data')

# %% [markdown]
# # Working with Thermal band

# %%
importlib.reload(tiffutils)

sitenames = ['hawaiihonolulularge']
for sitename in sitenames:
    print(f'{sitename}-------------------------------------')
    tiff_fns = glob(os.path.join('data', 'sat_images', sitename, '*', '*.tif'))
    for tiff_fn in tiff_fns:
        if '.TIR.tif' in tiff_fn: continue
        if 'L7' in tiff_fn: continue
        plot_scale = 1
        if 'S2' in tiff_fn:
            plot_scale = 5_000
        # else: continue
        print(tiff_fn)
        tiffutils.load_tiff_image(tiff_fn, plot=True, plot_scale=plot_scale)

        satname = os.path.basename(os.path.dirname(tiff_fn))
        timestamp = os.path.basename(tiff_fn).replace(f'{satname}_', '').replace('.tif', '')

        TIR_fn = glob(os.path.join('data', 'sat_images', sitename, satname, f'{satname}*{timestamp}*.TIR.tif'))[0]

        tiffutils.load_single_band_tiff_image(TIR_fn, plot=True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# hawaiihonolulularge-------------------------------------
# data\sat_images\hawaiihonolulularge\L8\L8_20200812_065045.tif
# (5, 549, 565)
# c:\Users\jnicolow\Documents\research\CRC\GEEdownload\geedownload\tiffutils.py:102: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# data\sat_images\hawaiihonolulularge\L8\L8_20200821_064045.tif
# (5, 549, 565)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# data\sat_images\hawaiihonolulularge\L8\L8_20200828_065045.tif
# (5, 549, 565)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
