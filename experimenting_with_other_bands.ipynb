# %%
import os
from glob import glob
import importlib
from geedownload import geeutils
importlib.reload(geeutils)
from geedownload import tiffutils
importlib.reload(tiffutils)

data_dir = os.path.join('data')

# %% [markdown]
# # Working with Thermal band

# %%
from glob import glob
sitenames = ['hawaiihonolulu']
for sitename in sitenames:
    print(f'{sitename}-------------------------------------')
    tiff_fns = glob(os.path.join('data', 'sat_images', sitename, '*', '*.tif'))
    for tiff_fn in tiff_fns:
        if '.TIR.tif' in tiff_fn: continue
        plot_scale = 1
        if 'S2' in tiff_fn:
            plot_scale = 10_000
        # else: continue
        print(tiff_fn)
        tiffutils.load_tiff_image(tiff_fn, plot=True, plot_scale=plot_scale)
# Out:
# hawaiihonolulu-------------------------------------
# data\sat_images\hawaiihonolulu\L7\L7_20200617_065045.tif
# (5, 181, 335)
# c:\Users\jnicolow\Documents\research\CRC\GEEdownload\geedownload\tiffutils.py:48: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# data\sat_images\hawaiihonolulu\L7\L7_20200626_064045.tif
# (5, 181, 335)
# data\sat_images\hawaiihonolulu\L7\L7_20200703_065045.tif
# (5, 181, 335)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# data\sat_images\hawaiihonolulu\L7\L7_20200712_064045.tif
# (5, 181, 335)
# data\sat_images\hawaiihonolulu\L7\L7_20200719_065045.tif
# (5, 181, 335)
# data\sat_images\hawaiihonolulu\L7\L7_20200728_064045.tif
# (5, 181, 335)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# data\sat_images\hawaiihonolulu\L8\L8_20200618_064045.tif
# (5, 181, 335)
# data\sat_images\hawaiihonolulu\L8\L8_20200625_065045.tif
# (5, 181, 335)
# data\sat_images\hawaiihonolulu\L8\L8_20200704_064045.tif
# (5, 181, 335)
# data\sat_images\hawaiihonolulu\L8\L8_20200711_065045.tif
# (5, 181, 335)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# data\sat_images\hawaiihonolulu\L8\L8_20200720_064045.tif
# (5, 181, 335)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# data\sat_images\hawaiihonolulu\L8\L8_20200727_065045.tif
# (5, 181, 335)
