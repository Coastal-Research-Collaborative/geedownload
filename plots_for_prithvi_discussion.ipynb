# %%
import os
from glob import glob
import importlib


from geedownload import tiffutils
from geedownload import dataplots

# %% [markdown]
# # plots for prithvi paper discussion

# %%
importlib.reload(tiffutils)
importlib.reload(dataplots)
sitename = 'michigangreatbearlake'
satname = 'S2'

winter_image = 'S2_20240221_163311'
summer_image = 'S2_20240804_162839'

summer_images = glob(os.path.join('data', 'sat_images', sitename, satname, f'*{summer_image}*.tif'))
winter_images = glob(os.path.join('data', 'sat_images', sitename, satname, f'*{winter_image}*.tif'))


dataplots.plot_satellite_bands(summer_images)

# %%
summer_images
# Out:
# ['data\\sat_images\\michigangreatbearlake\\S2\\S2_20240804_162839.swir1.tif',
#  'data\\sat_images\\michigangreatbearlake\\S2\\S2_20240804_162839.swir2.tif',
#  'data\\sat_images\\michigangreatbearlake\\S2\\S2_20240804_162839.tif']
